# %%
import pandas as pd

df_m = pd.read_excel('201311_201311_연령별인구현황_월간.xlsx', skiprows=3, index_col='행정기관', usecols='B, E:Y')
df_m
# Out:
# C:\Users\gnaaak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                 0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         1,182,795  1,201,545  1,472,506  1,805,131  1,799,475  1,652,677
# 서울특별시        209,952    206,594    251,614    321,481    349,617    381,684
# 부산광역시         68,272     67,504     87,995    118,501    129,046    112,978
# 대구광역시         52,794     56,681     75,939     97,466     98,298     78,945
# 인천광역시         69,892     68,816     82,110    102,859    107,461     96,328
# 광주광역시         36,605     39,520     51,353     61,506     55,521     46,261
# 대전광역시         38,238     39,931     48,295     59,265     58,231     51,773
# ...

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int) 
df_m
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         1182795  1201545  1472506  1805131  1799475  1652677  2087517
# 서울특별시      209,952  206,594  251,614  321,481  349,617  381,684  477,525
# 부산광역시       68,272   67,504   87,995  118,501  129,046  112,978  138,783
# 대구광역시       52,794   56,681   75,939   97,466   98,298   78,945   91,790
# 인천광역시       69,892   68,816   82,110  102,859  107,461   96,328  123,279
# 광주광역시       36,605   39,520   51,353   61,506   55,521   46,261   59,254
# 대전광역시       38,238   39,931   48,295   59,265   58,231   51,773   62,269
# 울산광역시       29,912   29,111   36,293   47,524   46,227   38,571   49,673
# 세종특별자치시      3,241    3,303    3,438    3,507    3,635    3,629    4,720
# 경기도        317,043  326,057  382,130  443,170  424,336  389,003  512,295
# 강원도         31,330   34,470   44,302   53,420   55,975   44,497   51,164
# 충청북도        36,978   37,633   46,500   56,679   55,100   49,344   59,101
# ...

# %%
df_w = pd.read_excel('201311_201311_연령별인구현황_월간.xlsx', skiprows=3, index_col='행정기관', usecols='B, AB:AV')
df_w
# Out:
# C:\Users\gnaaak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국         1,117,434  1,124,369  1,349,738  1,621,535  1,600,038  1,539,222
# 서울특별시        199,101    194,736    233,454    293,434    341,377    391,233
# 부산광역시         64,733     63,427     79,578    103,151    112,152    105,618
# 대구광역시         49,783     52,139     67,121     83,580     78,057     68,093
# 인천광역시         66,210     65,000     76,533     93,670     98,464     90,985
# 광주광역시         34,263     36,769     47,103     56,723     50,375     44,807
# 대전광역시         36,041     37,421     44,406     53,089     51,374     47,779
# ...

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns = df_m.columns # 컬럼명 통일

# %%
df_w
# Out:
#                 0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         1,117,434  1,124,369  1,349,738  1,621,535  1,600,038  1,539,222
# 서울특별시        199,101    194,736    233,454    293,434    341,377    391,233
# 부산광역시         64,733     63,427     79,578    103,151    112,152    105,618
# 대구광역시         49,783     52,139     67,121     83,580     78,057     68,093
# 인천광역시         66,210     65,000     76,533     93,670     98,464     90,985
# 광주광역시         34,263     36,769     47,103     56,723     50,375     44,807
# 대전광역시         36,041     37,421     44,406     53,089     51,374     47,779
# 울산광역시         28,116     26,538     32,155     40,238     36,028     32,309
# 세종특별자치시        3,176      3,238      3,257      3,103      3,098      2,944
# 경기도          300,185    307,812    354,275    405,569    392,107    367,104
# 강원도           29,529     31,760     40,329     48,111     43,969     35,923
# ...

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int)

# %%
# 데이터 시각화 
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글 글씨체
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False # 음수 사용

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000) # 단위 천명
plt.barh(df_w.columns, df_w.iloc[0] // 1000) # 단위 천명
plt.title('2011년 대한민국 인구 피라미드')
plt.savefig('2011_인구피라미드.png', dpi=100)
plt.show()
